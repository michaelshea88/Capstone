# %%
from yummly import Client
import json
import requests
import pandas as pd
import numpy as np

# %%
TIMEOUT = 5.0
RETRIES = 0
headers= {'X-Yummly-App-ID':'79663a75', 'X-Yummly-App-Key':'02b233108f476f3110e0f65437c4d6dd'}
# #client = Client(api_id='79663a75', api_key='02b233108f476f3110e0f65437c4d6dd', timeout=TIMEOUT, retries=RETRIES)

# #search = client.search('green eggs and ham')
# match = search.matches[0]

# recipe = client.recipe(match.id)

# %%
headers= {'X-Yummly-App-ID':'79663a75', 'X-Yummly-App-Key':'02b233108f476f3110e0f65437c4d6dd'}
url='http://api.yummly.com/v1/api/recipes?'
parameters={'q': 'chicken',
            'maxResult': 40}

response=requests.get(url,headers=headers, params=parameters)

# %%
response.status_code
# Out:
# 200

# %%
chicken=response.json()
type(chicken)
# Out:
# dict

# %%
chicken.keys()
# Out:
# [u'matches', u'totalMatchCount', u'attribution', u'facetCounts', u'criteria']

# %%
chicken['matches'][0]
# Out:
# {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Kid-Friendly']},
#  u'flavors': {u'bitter': 0.5,
#   u'meaty': 0.6666666666666666,
#   u'piquant': 0.0,
#   u'salty': 0.6666666666666666,
#   u'sour': 0.3333333333333333,
#   u'sweet': 0.16666666666666666},
#  u'id': u'Pizza-Baked-Chicken-1706825',
#  u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/5OqwvMJ6X8PW6rVWsV2vW8cRQYDkNxANIAr4Rf3wDWDl-6g2wfH7iMCmCFYnJXBA8OoFBdUOQri9H5UyoKL5YUU=s90-c'},
#  u'ingredients': [u'pizza sauce',
#   u'skinless chicken breasts',
#   u'olive oil',
#   u'oregano',
#   u'garlic powder',
#   u'mozzarella cheese',
#   u'pepperoni slices'],
#  u'rating': 4,
#  u'recipeName': u'Pizza Baked Chicken',
#  u'smallImageUrls': [u'https://lh3.googleusercontent.com/gw3fhUAtYflDTtpcdR0k1fItxmHYie8Lm3occLD2WQP7VXXQqgoSg8o-IAND1d1QGUAbmwYuHYhgAuA4LzTMGw=s90'],
#  u'sourceDisplayName': u'Get In My Belly',
#  u'totalTimeInSeconds': 3000}

# %%
# all column names
chicken_matches = chicken['matches']

main=['id','rating','recipeName','sourceDisplayName','totalTimeInSeconds']
ingredients=['id', 'ingredients']
attributes=['id', 'attributes']

# %%
#x[0]-dictionary of one recipe
main_list = []
ingredients_list = []
attributes_list = []


for food in chicken_matches:

    _d1 = {}
    _d1['id'] = food['id']
    _d1['rating'] = food['rating']
    _d1['recipeName'] = food['recipeName']
    _d1['sourceDisplayName'] = food['sourceDisplayName']
    _d1['totalTimeInSeconds'] = food['totalTimeInSeconds'] 
    main_list.append(_d1)
    
    _d2 = {}
    _d2['id'] =food['id']
    for i in food['ingredients']:
        _d2[i] = 1
    ingredients_list.append(_d2)

    _d3 = {}
    _d3['_id'] = food['id']
    for k, v in food['attributes'].items():
        for i in v:
            _d3[i] = 1
    attributes_list.append(_d3)
    
from pprint import pprint
pprint(main_list[0])
pprint(ingredients_list[0])
pprint(attributes_list[4])
# Out:
# {'id': u'Pizza-Baked-Chicken-1706825',
#  'rating': 4,
#  'recipeName': u'Pizza Baked Chicken',
#  'sourceDisplayName': u'Get In My Belly',
#  'totalTimeInSeconds': 3000}
# {u'garlic powder': 1,
#  'id': u'Pizza-Baked-Chicken-1706825',
#  u'mozzarella cheese': 1,
#  u'olive oil': 1,
#  u'oregano': 1,
#  u'pepperoni slices': 1,
#  u'pizza sauce': 1,
#  u'skinless chicken breasts': 1}
# {u'Barbecue': 1, u'Main Dishes': 1, '_id': u'Beer-Can-Chicken-1637442'}

# %%
df_main =pd.DataFrame(main_list)
df_ingredients =pd.DataFrame(ingredients_list)
df_attributes =pd.DataFrame(attributes_list)

df_main
df_ingredients
df_attributes
# Out:
#                                                    id  rating  \
# 0                         Pizza-Baked-Chicken-1706825       4
# 1                   Parmesan-Chicken-Mini-Pies-685394       4
# 2                Chicken-and-Avocado-Burritos-1704783       4
# 3                    Chicken-Tortilla-Skillet-1704990       4
# 4                            Beer-Can-Chicken-1637442       3
# 5                      SHREDDED-CHICKEN-TACOS-1680208       4
# 6     CHICKEN-BREASTS-WITH-GARLIC-AND-PARSLEY-1678533       4
# 7                Chicken-_-Dumpling-Casserole-1684937       4
# 8   Crispy-Sesame-Chicken-with-a-Sticky-Asian-Sauc...       4
# 9            Crispy-Cheesy-Buttermilk-Chicken-1706370       4
# 10                    Easy-BBQ-Pulled-Chicken-1706371       4
# 11  15-Minute-Healthy-Roasted-Chicken-and-Veggies-...       4
# 12                  Baked-Firecracker-Chicken-1698380       4
# 13                 Chipotle-Chicken-Ranch-Dip-1705157       4
# 14                      Cilantro-Lime-Chicken-1702564       4
# 15               Lemon-Butter-Chicken-Breasts-1690972       3
# 16                      Easy-Chicken-Teriyaki-1683493       4
# 17               Buffalo-Chicken-Crescent-Ring-768364       4
# 18                    Hawaiian-Chicken-Kabobs-1683785       4
# 19                           Chicken-Souvlaki-1706366       4
# 20        The-Ultimate-Southern-Fried-Chicken-1682151       3
# 21                        Man-Pleasing-Chicken-608913       3
# 22                  Easy-BBQ-Chicken-Crescents-685393       4
# 23                Fried-Chicken-_SundaySupper-1699353       4
# 24          Jerk-Chicken-with-Pineapple-Salsa-1703129       4
# 25                        Asian-Honey-Chicken-1634071       4
# 26                 Pesto-Chicken-Crescent-Ring-768366       4
# 27                6-Ingredient-Orange-Chicken-1614114       4
# 28             Creamy-Chicken-Spinach-Skillet-1703655       4
# 29                     Baked-Chicken-Parmesan-1639330       4
# 30                       Baked-Barbecue-Wings-1705141       4
# 31                        Baked-Pesto-Chicken-1687730       3
# 32                  Easy-Pulled-Chicken-Chili-1706372       4
# 33                       Lemon-Butter-Chicken-1602780       4
# 34              Grilled-Chili-Chicken-Breasts-1695964       4
# 35                   THE-WORLD_S-BEST-CHICKEN-1704380       4
# 36     One-Pot-Chicken-Bacon-Chipotle-Alfredo-1636699       3
# 37                      Greek-Chicken---Paleo-1623596       4
# 38                      Baked-Italian-Chicken-1705652       4
# 39                     Garlic-Chicken-Piccata-1701575       4
#
#                                          recipeName  \
# 0                               Pizza Baked Chicken
# 1                        Parmesan Chicken Mini Pies
# 2                      Chicken and Avocado Burritos
# 3                          Chicken Tortilla Skillet
# 4                                  Beer Can Chicken
# 5                            SHREDDED CHICKEN TACOS
# 6           CHICKEN BREASTS WITH GARLIC AND PARSLEY
# 7                      Chicken & Dumpling Casserole
# 8   Crispy Sesame Chicken with a Sticky Asian Sauce
# 9                  Crispy Cheesy Buttermilk Chicken
# 10                          Easy BBQ Pulled Chicken
# 11    15 Minute Healthy Roasted Chicken and Veggies
# 12                        Baked Firecracker Chicken
# 13                       Chipotle Chicken Ranch Dip
# 14                            Cilantro Lime Chicken
# 15                     Lemon Butter Chicken Breasts
# 16                            Easy Chicken Teriyaki
# 17                    Buffalo Chicken Crescent Ring
# 18                          Hawaiian Chicken Kabobs
# 19                                 Chicken Souvlaki
# 20              The Ultimate Southern Fried Chicken
# 21                             Man-Pleasing Chicken
# 22                       Easy BBQ Chicken Crescents
# 23                      Fried Chicken #SundaySupper
# 24                Jerk Chicken with Pineapple Salsa
# 25                              Asian Honey Chicken
# 26                      Pesto Chicken Crescent Ring
# 27                      6-Ingredient Orange Chicken
# 28                   Creamy Chicken Spinach Skillet
# 29                           Baked Chicken Parmesan
# 30                             Baked Barbecue Wings
# 31                              Baked Pesto Chicken
# 32                        Easy Pulled Chicken Chili
# 33                             Lemon Butter Chicken
# 34                    Grilled Chili Chicken Breasts
# 35                         THE WORLD'S BEST CHICKEN
# 36           One-Pot Chicken-Bacon-Chipotle Alfredo
# 37                            Greek Chicken - Paleo
# 38                            Baked Italian Chicken
# 39                           Garlic Chicken Piccata
#
#                sourceDisplayName  totalTimeInSeconds
# 0                Get In My Belly                3000
# 1                           None                1500
# 2                 Closet Cooking                1200
# 3       Healthy Seasonal Recipes                1500
# 4                     Perdue.com                6000
# 5                  Enjoy cooking                2100
# 6         Linda's Low Carb Menus                1200
# 7                   HRecipes.com                6300
# 8              Kitchen Sanctuary                1800
# 9                  Hungry Couple                2700
# 10                 Hungry Couple                2400
# 11                  Yummy Recipe                2700
# 12              Little Spice Jar                3300
# 13              Chef In Training                2100
# 14                   Add a Pinch                1500
# 15      Better Homes and Gardens                1800
# 16                 Melanie Cooks                1200
# 17                          None                2700
# 18            Spend with Pennies                2580
# 19                 Hungry Couple                3600
# 20                   Food & Wine                2700
# 21             Witty in the City                3300
# 22                          None                1200
# 23                 Tramplingrose                2100
# 24  Dinners, Dishes and Desserts                5100
# 25               Get In My Belly                1500
# 26                          None                2700
# 27                     Skinny Ms                2400
# 28                  Eat Well 101                2100
# 29                 Enjoy cooking                2700
# 30       For the Love of Cooking                3300
# 31                         Meals                2400
# 32                 Hungry Couple                2100
# 33               Dariuscooks.Com                2100
# 34               No Fail Recipes                2400
# 35                Rachel Schultz                2700
# 36                    Tablespoon                1200
# 37             Jessy and Melissa              174600
# 38                Kim's Cravings                2100
# 39           Served From Scratch                3900
