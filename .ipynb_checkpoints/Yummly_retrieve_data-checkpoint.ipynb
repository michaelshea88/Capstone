# %%
from yummly import Client
import json
import requests
import pandas as pd
import numpy as np

# %%
TIMEOUT = 5.0
RETRIES = 0
headers= {'X-Yummly-App-ID':'79663a75', 'X-Yummly-App-Key':'02b233108f476f3110e0f65437c4d6dd'}
client = Client(api_id='79663a75', api_key='02b233108f476f3110e0f65437c4d6dd', timeout=TIMEOUT, retries=RETRIES)

search = client.search('green eggs and ham')
match = search.matches[0]

recipe = client.recipe(match.id)

# %%
url='http://api.yummly.com/v1/api/recipes?'
parameters={'q': 'chicken',
            'maxResult': 40}

response=requests.get(url,headers=headers, params=parameters)

# %%
response.status_code
# Out:
# 200

# %%
chicken=response.json()
type(chicken)

# %%
chicken.keys()
# Out:
# [u'matches', u'totalMatchCount', u'attribution', u'facetCounts', u'criteria']

# %%
chicken['matches'][0]
# Out:
# {u'attributes': {u'course': [u'Main Dishes', u'Lunch'],
#   u'cuisine': [u'Southwestern']},
#  u'flavors': {u'bitter': 0.8333333333333334,
#   u'meaty': 0.8333333333333334,
#   u'piquant': 0.5,
#   u'salty': 0.6666666666666666,
#   u'sour': 0.16666666666666666,
#   u'sweet': 0.16666666666666666},
#  u'id': u'Chicken-and-Avocado-Burritos-1704783',
#  u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/eeB9rCeMVPDhHZxPEb437Z9AlQu4bPu0NCfc2xoWcOeca3p1ujmeqrr7Lv5tgsqcGL-2YroEf3-0ODkUSUIt7qI=s90-c'},
#  u'ingredients': [u'tortillas',
#   u'cooked chicken',
#   u'avocado',
#   u'monterey jack',
#   u'salsa verde',
#   u'sour cream',
#   u'cilantro'],
#  u'rating': 4,
#  u'recipeName': u'Chicken and Avocado Burritos',
#  u'smallImageUrls': [u'https://lh3.googleusercontent.com/3A0pEbxCtYK_UK3gpCI3GHzzAvBpNTVH0Jauu0es3lpU86iTKcfQu4ggP0JkGvhHXuPVTedExLWPdMl8mchKdLo=s90'],
#  u'sourceDisplayName': u'Closet Cooking',
#  u'totalTimeInSeconds': 1200}

# %%
# all column names
chicken_matches = chicken['matches']

main=['id','rating','recipeName','sourceDisplayName','totalTimeInSeconds']
ingredients=['id', 'ingredients']
attributes=['id', 'attributes']

print keys
# Out:
# [u'flavors', u'rating', u'totalTimeInSeconds', u'ingredients', u'smallImageUrls', u'sourceDisplayName', u'recipeName', u'attributes', u'id', u'imageUrlsBySize']

# %%
#x[0]-dictionary of one recipe
main_list = []
ingredients_list = []
attributes_list = []


for food in chicken_matches:

    _d1 = {}
    _d1['id'] = food['id']
    _d1['rating'] = food['rating']
    _d1['recipeName'] = food['recipeName']
    _d1['sourceDisplayName'] = food['sourceDisplayName']
    _d1['totalTimeInSeconds'] = food['totalTimeInSeconds'] 
    main_list.append(_d1)
    
    _d2 = {}
    _d2['id'] =food['id']
    _d2['ingredients'] = food['ingredients']
    ingredients_list.append(_d2)

    _d3 = {}
    _d3['_id'] = food['id']
    for k, v in food['attributes'].items():
        if k == 'course':
            if 'Main Dish' in v:
                _d3['Main Dish'] = 1
            else:
                _d3['Main Dish'] = 0
            if 'Lunch' in v:
                _d3['Lunch'] = 1
            else:
                _d3['Lunch'] = 0
            
        _d3[k] = v
    attributes_list.append(_d3)
    
from pprint import pprint
pprint(main_list[0])
pprint(ingredients_list[0])
pprint(attributes_list[4])
# Out:
# {'id': u'Chicken-and-Avocado-Burritos-1704783',
#  'rating': 4,
#  'recipeName': u'Chicken and Avocado Burritos',
#  'sourceDisplayName': u'Closet Cooking',
#  'totalTimeInSeconds': 1200}
# {'id': u'Chicken-and-Avocado-Burritos-1704783',
#  'ingredients': [u'tortillas',
#                  u'cooked chicken',
#                  u'avocado',
#                  u'monterey jack',
#                  u'salsa verde',
#                  u'sour cream',
#                  u'cilantro']}
# {'_id': u'SHREDDED-CHICKEN-TACOS-1680208',
#  u'course': [u'Main Dishes'],
#  u'cuisine': [u'Kid-Friendly']}

# %%
df_main =pd.DataFrame(main_list)
df_ingredients =pd.DataFrame(ingredients_list)
df_attributes =pd.DataFrame(attributes_list)

df_main
df_ingredients
df_attributes
# Out:
#                                                   _id                course  \
# 0                Chicken-and-Avocado-Burritos-1704783  [Main Dishes, Lunch]
# 1                   Parmesan-Chicken-Mini-Pies-685394                   NaN
# 2                            Beer-Can-Chicken-1637442         [Main Dishes]
# 3     CHICKEN-BREASTS-WITH-GARLIC-AND-PARSLEY-1678533         [Main Dishes]
# 4                      SHREDDED-CHICKEN-TACOS-1680208         [Main Dishes]
# 5   Crispy-Sesame-Chicken-with-a-Sticky-Asian-Sauc...         [Main Dishes]
# 6                Chicken-_-Dumpling-Casserole-1684937         [Main Dishes]
# 7                     Hawaiian-Chicken-Kabobs-1683785         [Main Dishes]
# 8                Lemon-Butter-Chicken-Breasts-1690972         [Main Dishes]
# 9                Buffalo-Chicken-Crescent-Ring-768364         [Main Dishes]
# 10                 Pesto-Chicken-Crescent-Ring-768366         [Main Dishes]
# 11                      Easy-Chicken-Teriyaki-1683493         [Main Dishes]
# 12                      Cilantro-Lime-Chicken-1702564         [Main Dishes]
# 13                  Easy-BBQ-Chicken-Crescents-685393               [Lunch]
# 14  15-Minute-Healthy-Roasted-Chicken-and-Veggies-...  [Main Dishes, Lunch]
# 15                        Asian-Honey-Chicken-1634071         [Main Dishes]
# 16                        Man-Pleasing-Chicken-608913         [Main Dishes]
# 17                  Baked-Firecracker-Chicken-1698380         [Main Dishes]
# 18                6-Ingredient-Orange-Chicken-1614114         [Main Dishes]
# 19                       Lemon-Butter-Chicken-1602780         [Main Dishes]
# 20                     Garlic-Chicken-Piccata-1701575         [Main Dishes]
# 21                        Baked-Pesto-Chicken-1687730         [Main Dishes]
# 22     One-Pot-Chicken-Bacon-Chipotle-Alfredo-1636699         [Main Dishes]
# 23          Jerk-Chicken-with-Pineapple-Salsa-1703129         [Main Dishes]
# 24        The-Ultimate-Southern-Fried-Chicken-1682151         [Main Dishes]
# 25                     Baked-Chicken-Parmesan-1639330  [Lunch, Main Dishes]
# 26                      Greek-Chicken---Paleo-1623596         [Main Dishes]
# 27                           Teriyaki-Chicken-1704307         [Main Dishes]
# 28               Chicken-Cashew-Spinach-Wraps-1701367               [Lunch]
# 29              Grilled-Chili-Chicken-Breasts-1695964         [Main Dishes]
# 30                               Chicken-Pate-1705074                   NaN
# 31                Buffalo-Chicken-Sloppy-Joes-1703842  [Main Dishes, Lunch]
# 32           Slow-Cooker-Honey-Sesame-Chicken-1704099         [Main Dishes]
# 33                        Baked-Lemon-Chicken-1623832         [Main Dishes]
# 34      Paula-Deens-amazing-chicken-casserole-1679543         [Main Dishes]
# 35               2-ingredient-Paprika-Chicken-1650890         [Main Dishes]
# 36            Chicken-Fajita-Foil-Packet-Meal-1684657         [Main Dishes]
# 37               Chicken-with-Rice-in-one-pot-1623406                   NaN
# 38         Badami-Chicken---Almond-Milk-Curry-1702076         [Main Dishes]
# 39                     Everyday-Baked-Chicken-1581195         [Main Dishes]
#
#                                  cuisine         holiday
# 0                         [Southwestern]             NaN
# 1                         [Kid-Friendly]             NaN
# 2                             [Barbecue]             NaN
# 3                                    NaN             NaN
# 4                         [Kid-Friendly]             NaN
# 5                                [Asian]             NaN
# 6                                    NaN             NaN
# 7                   [Barbecue, Hawaiian]             NaN
# 8                                    NaN             NaN
# 9                                    NaN             NaN
# 10                        [Kid-Friendly]             NaN
# 11                               [Asian]             NaN
# 12                                   NaN             NaN
# 13              [Barbecue, Kid-Friendly]             NaN
# 14                                   NaN             NaN
# 15                               [Asian]             NaN
# 16                                   NaN             NaN
# 17                                   NaN             NaN
# 18                                   NaN             NaN
# 19                                   NaN             NaN
# 20                                   NaN             NaN
# 21                        [Kid-Friendly]             NaN
# 22                                   NaN             NaN
# 23                            [Barbecue]             NaN
# 24  [Kid-Friendly, Southern & Soul Food]             NaN
# 25                        [Kid-Friendly]             NaN
# 26                     [Barbecue, Greek]             NaN
# 27                            [Barbecue]             NaN
# 28                                   NaN             NaN
# 29                            [Barbecue]             NaN
# 30                                   NaN             NaN
# 31                                   NaN             NaN
# 32                                   NaN             NaN
# 33                                   NaN  [Sunday Lunch]
# 34                                   NaN             NaN
# 35                                   NaN             NaN
# 36                                   NaN             NaN
# 37                                   NaN             NaN
# 38                              [Indian]             NaN
# 39                                   NaN             NaN

# %%
_dict={}
for recipe in recipes:
    for key in recipe.keys():
        if key in keys1:
            _dict[key]=
# Out:
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize
# flavors
# rating
# totalTimeInSeconds
# ingredients
# smallImageUrls
# sourceDisplayName
# recipeName
# attributes
# id
# imageUrlsBySize

# %%
_dict={}
for rec in x:
    if i[0] in keys1:
        _dict[i[0]]=i[1]
_dict
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-2a7b70c1a48d> in <module>()
#       1 _dict={}
#       2 for recipe in x:
# ----> 3     if i[0] in keys1:
#       4         _dict[i[0]]=i[1]
#       5 _dict
#
# KeyError: 0

# %%
x
# Out:
# [{u'attributes': {u'course': [u'Main Dishes', u'Lunch'],
#    u'cuisine': [u'Southwestern']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.5,
#    u'salty': 0.6666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-and-Avocado-Burritos-1704783',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/eeB9rCeMVPDhHZxPEb437Z9AlQu4bPu0NCfc2xoWcOeca3p1ujmeqrr7Lv5tgsqcGL-2YroEf3-0ODkUSUIt7qI=s90-c'},
#   u'ingredients': [u'tortillas',
#    u'cooked chicken',
#    u'avocado',
#    u'monterey jack',
#    u'salsa verde',
#    u'sour cream',
#    u'cilantro'],
#   u'rating': 4,
#   u'recipeName': u'Chicken and Avocado Burritos',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/3A0pEbxCtYK_UK3gpCI3GHzzAvBpNTVH0Jauu0es3lpU86iTKcfQu4ggP0JkGvhHXuPVTedExLWPdMl8mchKdLo=s90'],
#   u'sourceDisplayName': u'Closet Cooking',
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'Parmesan-Chicken-Mini-Pies-685394',
#   u'imageUrlsBySize': {u'90': u'http://lh6.ggpht.com/_wrxTIqsE0MXud2-GGyAxQiAzVbKfQgY-2jvhtNGvwKrkWi2zBNQPfrgDgU-mjlP1OdvtWF70fvtItzZoYrt=s90-c'},
#   u'ingredients': [u'dough',
#    u'Tyson\xae frozen popcorn chicken pieces',
#    u'tomato sauce',
#    u'shredded parmesan cheese'],
#   u'rating': 4,
#   u'recipeName': u'Parmesan Chicken Mini Pies',
#   u'smallImageUrls': [u'http://lh5.ggpht.com/_8h6rpOPQqn7wTfjgfI-SPMRE0EPQmI612KFCRlanaMcTb1-8gXv0c4ewV4qOTdc4_EmZlv7mrAYjIN9JZscaDQ=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 1500},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 1.0,
#    u'meaty': 1.0,
#    u'piquant': 0.0,
#    u'salty': 1.0,
#    u'sour': 1.0,
#    u'sweet': 1.0},
#   u'id': u'Beer-Can-Chicken-1637442',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/JyOvQ3GOyDDiCe5btUqg6l2oL9-iqwQ-sxX37ZNebBfN6qecZYKHTHeoTmITgbmRHQMPd7lZhWhV69oV27C2=s90-c'},
#   u'ingredients': [u'chicken',
#    u'salt',
#    u'fresh thyme',
#    u'garlic powder',
#    u'onion powder',
#    u'black pepper',
#    u'vegetable oil',
#    u'beer'],
#   u'rating': 3,
#   u'recipeName': u'Beer Can Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/OlJR7_Ga81cq0KXo0ru7PStGQaUg5RTvWm2W-SlD5IjRQMosS3XrYUamGpFF4-U0IzU0Pqau3u_rlFkYx8s7=s90'],
#   u'sourceDisplayName': u'Perdue.com',
#   u'totalTimeInSeconds': 6000},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.5,
#    u'sweet': 0.0},
#   u'id': u'CHICKEN-BREASTS-WITH-GARLIC-AND-PARSLEY-1678533',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/jxMp_NUTX9KLBLhFnO1JNHGquPEJRKIsykZrh0b4-K2IX9mDr7tD6evxwO85fCEKKCWtd5RKG3WkaFT0atp99U4=s90-c'},
#   u'ingredients': [u'boneless chicken breast',
#    u'flour',
#    u'salt',
#    u'pepper',
#    u'oil',
#    u'garlic',
#    u'fresh parsley',
#    u'butter'],
#   u'rating': 4,
#   u'recipeName': u'CHICKEN BREASTS WITH GARLIC AND PARSLEY',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/PUiQXvdls6AutTxs5bntntLfva3FZFt2D8Rhav9x95ENxuzGmdiyHivOH33gcRrKlydFuNdf1NgaZAvC42hb6WU=s90'],
#   u'sourceDisplayName': u"Linda's Low Carb Menus",
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'SHREDDED-CHICKEN-TACOS-1680208',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/hlpwQGvrd0w6wCoS1NT5tYrVGnqpLVq8A8bC3sAnI11iuS0Ai8xuhpIVrGYvmZN3HbPCD27GPeTzklwSto2S8w=s90-c'},
#   u'ingredients': [u'taco seasoning',
#    u'chicken broth',
#    u'boneless skinless chicken breasts',
#    u'salsa'],
#   u'rating': 4,
#   u'recipeName': u'SHREDDED CHICKEN TACOS',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/84Xeq2o4y1IMZtM9_7rpjHujimx2VWkyZlD_ar87-b8QTy7dXFK_s_qQAupRxpbbukGenq2DkR9RfmYhbaHt=s90'],
#   u'sourceDisplayName': u'Enjoy cooking',
#   u'totalTimeInSeconds': 2100},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Asian']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.5,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.5},
#   u'id': u'Crispy-Sesame-Chicken-with-a-Sticky-Asian-Sauce-1690758',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/fffnh9iuQAsbl0pu_ks6qwprumQk8T4k3XnGmHV5Qtfmgqh7Tye0k0rK-w2xiQZJHqrxZ37ZmnWXY3DKs9_1lA=s90-c'},
#   u'ingredients': [u'olive oil',
#    u'eggs',
#    u'corn flour',
#    u'all-purpose flour',
#    u'salt',
#    u'pepper',
#    u'garlic salt',
#    u'paprika',
#    u'chicken breast fillets',
#    u'sauce',
#    u'garlic',
#    u'Chinese rice vinegar',
#    u'honey',
#    u'sweet chili sauce',
#    u'ketchup',
#    u'brown sugar',
#    u'soy sauce',
#    u'rice',
#    u'sesame seeds',
#    u'spring onions'],
#   u'rating': 4,
#   u'recipeName': u'Crispy Sesame Chicken with a Sticky Asian Sauce',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/0F50u2sWhT_oPNEIvrZdZ5lk7VXe672c-ezunbqEr86OPUBRTOHlqFEYztlnzThFW_by9BMJxuOIwTSCpwgs=s90'],
#   u'sourceDisplayName': u'Kitchen Sanctuary',
#   u'totalTimeInSeconds': 1800},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.16666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-_-Dumpling-Casserole-1684937',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/YfZ4524plaWmBLHBEiM_pGHVUdkZfUoleeYPAKrU7EXrin_8iwPPZpK7seZc-tbWBAzgCMQTch77ZNqB2LYsCXw=s90-c'},
#   u'ingredients': [u'chicken',
#    u'all-purpose flour',
#    u'milk',
#    u'unsalted butter',
#    u'cream of chicken soup',
#    u'chicken broth',
#    u'salt',
#    u'black pepper'],
#   u'rating': 4,
#   u'recipeName': u'Chicken & Dumpling Casserole',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/Z-lkljOUM4VFX_43FlbC-hWwplqHucgM663iqt3CXMPOBw7VPfLnBukFCHDAZCrlAe5j42BWezpChmvNAC20-tA=s90'],
#   u'sourceDisplayName': u'HRecipes.com',
#   u'totalTimeInSeconds': 6300},
#  {u'attributes': {u'course': [u'Main Dishes'],
#    u'cuisine': [u'Barbecue', u'Hawaiian']},
#   u'flavors': None,
#   u'id': u'Hawaiian-Chicken-Kabobs-1683785',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/VhFs2koEaCDU1b5MnUFduoEfUoDuwcF2CZ3N291D3p0FNF8lViOw4BbObHKiQtePZ8lgpttIkCN7mo8jRA8A84M=s90-c'},
#   u'ingredients': [u'bbq sauce',
#    u'pineapple juice',
#    u'boneless skinless chicken breasts',
#    u'mushrooms',
#    u'red bell pepper',
#    u'orange bell pepper',
#    u'pineapple',
#    u'green bell pepper',
#    u'purple onion'],
#   u'rating': 4,
#   u'recipeName': u'Hawaiian Chicken Kabobs',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/IyMjckwGVz9B6mk6Uh3GAcD6-ch5rCJpkjg0np7H9rd8HYmrtT11MBM7MWj7L9ugmFUt0W7uKaoV25G--8WVsjg=s90'],
#   u'sourceDisplayName': u'Spend with Pennies',
#   u'totalTimeInSeconds': 2580},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': None,
#   u'id': u'Lemon-Butter-Chicken-Breasts-1690972',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/VmcMOu0bZz4_d1f_RkBBEyZY5iFznDhX1znR22uFzEk7RNfi3waSGWZX_g78Kl6r4NGCUGPzgP_ATC2QTkPrW8s=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breast halves',
#    u'all-purpose flour',
#    u'salt',
#    u'lemon pepper seasoning',
#    u'butter',
#    u'lemon',
#    u'lemon juice',
#    u'cooked rice'],
#   u'rating': 3,
#   u'recipeName': u'Lemon Butter Chicken Breasts',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/qfr2TlGUO_dearJCYzQT9Y04lUQtQhsFKiAWYGqeBDqYgdgYcIqItEN-FSwl68hNYLAheqR-VmoSN2xLHgcytw=s90'],
#   u'sourceDisplayName': u'Better Homes and Gardens',
#   u'totalTimeInSeconds': 1800},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': None,
#   u'id': u'Buffalo-Chicken-Crescent-Ring-768364',
#   u'imageUrlsBySize': {u'90': u'http://lh5.ggpht.com/5lntnT8m0i0KPy7jgqq9h74SZvypAQ4wee8Qf1QsgrBX-cJ1LhE2UxNo77xHu0rSjMLukIEo9V1SIHj3_9ZAmw=s90-c'},
#   u'ingredients': [u'cream cheese',
#    u'hot sauce',
#    u'cooked chicken',
#    u'shredded Monterey Jack cheese',
#    u'Pillsbury\u2122 Refrigerated Crescent Dinner Rolls',
#    u'crumbled blue cheese'],
#   u'rating': 4,
#   u'recipeName': u'Buffalo Chicken Crescent Ring',
#   u'smallImageUrls': [u'http://lh6.ggpht.com/6QGrV6cd37Q5OjU9ugqd8rfIFTUGZMClUqFUpNeHPb9IL2eqNYLeD0yZMcUyJWab03lTzqq80ewnsxtY5GdG=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'Pesto-Chicken-Crescent-Ring-768366',
#   u'imageUrlsBySize': {u'90': u'http://lh6.ggpht.com/pG7VDczfsWxB86jpsGdasiKNPyk4aT74XnExrjNAcBwKBOlGD7TB2qbr0EE0Wl-eJY2BLp17XXQfhglACEpwsw=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'basil pesto',
#    u'shredded Monterey Jack cheese',
#    u'Pillsbury\u2122 Refrigerated Crescent Dinner Rolls'],
#   u'rating': 4,
#   u'recipeName': u'Pesto Chicken Crescent Ring',
#   u'smallImageUrls': [u'http://lh3.ggpht.com/j1NsPTVxLuU7esOb5BfbFuJDGQUmzKABElWHKZN6r9BKb8gcu0OB_jI_Cu4ipUQyndQERFvhyy7wEvDp_ao=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Asian']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.5,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.3333333333333333},
#   u'id': u'Easy-Chicken-Teriyaki-1683493',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/9r0sFw5oYQC_SEnDyJy7mOaXNQxgeBtxMecfmkyLfrEYMRFQfMtl7a2aV5baNKPU0YPGwFh529NyppwGoJcPFg=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'soy sauce',
#    u'mirin',
#    u'brown sugar',
#    u'white vinegar',
#    u'oil',
#    u'corn starch'],
#   u'rating': 4,
#   u'recipeName': u'Easy Chicken Teriyaki',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/DdlHBvMJGVULZgi9VB8_DKbOWsKz2DOXKjlDzt2iqQNYPkCZQJ59lTIhNaMsvG37D4dqRvcShFIzb-ZtFZqgV0s=s90'],
#   u'sourceDisplayName': u'Melanie Cooks',
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.5,
#    u'piquant': 0.3333333333333333,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.6666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Cilantro-Lime-Chicken-1702564',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/EuIlpI0ax-gH9Iygl90SSGcEyLq2p7vpgqy52vkIVUAj_t7FdgKbKeSBO3iahkrk2gzYlEf89L89CgR9bTYM3w=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'fresh cilantro',
#    u'lime',
#    u'olive oil',
#    u'salt',
#    u'ground cumin',
#    u'cayenne pepper'],
#   u'rating': 4,
#   u'recipeName': u'Cilantro Lime Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/ID9coEPZNWmlQMfJISvxtynTk_pNgRqk9J0Dhgm1CfdD1F68bb5hMgUB5zUmlI_Mkz3s-CX94lkgL65jW7Sv=s90'],
#   u'sourceDisplayName': u'Add a Pinch',
#   u'totalTimeInSeconds': 1500},
#  {u'attributes': {u'course': [u'Lunch'],
#    u'cuisine': [u'Barbecue', u'Kid-Friendly']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.5,
#    u'salty': 0.5,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Easy-BBQ-Chicken-Crescents-685393',
#   u'imageUrlsBySize': {u'90': u'http://lh3.ggpht.com/GoaIXesKJsOZxielWSLft2HlBeInCeTjBBpHj0TsCdbUMul66mcyG4NrefLYQOVYIukloJn0NweBqXA9StBcIw=s90-c'},
#   u'ingredients': [u'Pillsbury\u2122 Refrigerated Crescent Dinner Rolls',
#    u'chicken breast strips',
#    u'barbecue sauce',
#    u'shredded cheddar cheese'],
#   u'rating': 4,
#   u'recipeName': u'Easy BBQ Chicken Crescents',
#   u'smallImageUrls': [u'http://lh5.ggpht.com/PZQYFmdWajIlbSDUqYxT44T24xx8wSFM0-xlF_Hy7YuVLNqYW2ce0tgu_BPUH7XPBKv1V-vl7pJ5frfKZotruw=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes', u'Lunch']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.16666666666666666},
#   u'id': u'15-Minute-Healthy-Roasted-Chicken-and-Veggies-1702651',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/M0flzlCdYkLYfWQz_x1ZcEN9Ef4TIkGyy-R8GZY00nwffjQCjlg777zgHtJZfm-qGy3AMVkAju5okKtaI-_4sw=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'bell pepper',
#    u'onions',
#    u'zucchini',
#    u'broccoli florets',
#    u'tomatoes',
#    u'olive oil',
#    u'salt',
#    u'black pepper',
#    u'italian seasoning',
#    u'paprika'],
#   u'rating': 4,
#   u'recipeName': u'15 Minute Healthy Roasted Chicken and Veggies',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/R7aDtqU9dJpkXZXtokfopLcbLVrCVtWSjkejqqt1yDREScAcJwKs6EvGGdz1B_ET-t6lVOJk5TvpP3-jG4f_-A=s90'],
#   u'sourceDisplayName': u'Yummy Recipe',
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Asian']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.5,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.5,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.6666666666666666},
#   u'id': u'Asian-Honey-Chicken-1634071',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/ff2lqRliNtDKEAyncKR9dypADVA_5n7_2XDd72FYtcw1KBOXT3I9eN689j2tY1Gu9YZrlw_z5H2_n_glLlD1Fg=s90-c'},
#   u'ingredients': [u'vegetable oil',
#    u'boneless skinless chicken breasts',
#    u'all-purpose flour',
#    u'buttermilk',
#    u'apple cider vinegar',
#    u'sesame oil',
#    u'crushed red pepper flakes',
#    u'corn starch',
#    u'honey',
#    u'soy sauce'],
#   u'rating': 4,
#   u'recipeName': u'Asian Honey Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/tqgI1PKMD_MOOy6H43MjNl3kSBVwdi2XsTPfb1fpeEKPcizekh1YnyyPpdvejFKX647aqfjvyaFDQqfsRc1NwYE=s90'],
#   u'sourceDisplayName': u'Get In My Belly',
#   u'totalTimeInSeconds': 1500},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': None,
#   u'id': u'Man-Pleasing-Chicken-608913',
#   u'imageUrlsBySize': {u'90': u'http://lh5.ggpht.com/UwNbjIdEdFmkETuO0pjnBvhuPkgXVskHco3qA5lV1xInenr6jiXt3zljBt9-TptV_oi-xcG_TQuS3dltp-gURQ=s90-c'},
#   u'ingredients': [u'chicken thighs',
#    u'dijon mustard',
#    u'maple syrup',
#    u'rice vinegar',
#    u'fresh rosemary',
#    u'salt',
#    u'pepper'],
#   u'rating': 3,
#   u'recipeName': u'Man-Pleasing Chicken',
#   u'smallImageUrls': [u'http://lh4.ggpht.com/gInMhsmcQ708LZAw4ryeheSm6cOuvDtlzpHpbrE1RW01kYudZlWoRBcEiS-gj_2mj_8Xdl-dzgNY2CJxbHbT=s90'],
#   u'sourceDisplayName': u'Witty in the City',
#   u'totalTimeInSeconds': 3300},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.8333333333333334,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.6666666666666666,
#    u'sweet': 0.8333333333333334},
#   u'id': u'Baked-Firecracker-Chicken-1698380',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/hNG87LIMlvBnCBi-umN67SRrrcDAWc3hML8x2bJkNaqGSJnUpgh8zkncSHmSkQPHIhisRiW0v1Nn2Seno-aBcw=s90-c'},
#   u'ingredients': [u'hot sauce',
#    u'light brown sugar',
#    u'apple cider vinegar',
#    u'salt',
#    u'minced garlic',
#    u'red pepper flakes',
#    u'skinless chicken breasts',
#    u'pepper',
#    u'oil'],
#   u'rating': 4,
#   u'recipeName': u'Baked Firecracker Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/89aOBdn7t4ad8kQMgi6p8tuIdcIYxNJd3ZDNZXO3isFCpTyFKd31Q_Qx6nAoMRfIq8-MGSQ2Zo_ExAj5q2FR=s90'],
#   u'sourceDisplayName': u'Little Spice Jar',
#   u'totalTimeInSeconds': 3300},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.5,
#    u'meaty': 0.3333333333333333,
#    u'piquant': 0.6666666666666666,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.5},
#   u'id': u'6-Ingredient-Orange-Chicken-1614114',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/IhLP49GLhNDJ1x-agbz3k4E47a6Mj3YBLgFndC6sYgfD22lULxt_iQPvVHqrZmgHguLK0j1_C94LfXmuY58PKXE=s90-c'},
#   u'ingredients': [u'chicken breast fillets',
#    u'flour',
#    u'coconut oil',
#    u'navel oranges',
#    u'barbecue sauce',
#    u'light soy sauce'],
#   u'rating': 4,
#   u'recipeName': u'6-Ingredient Orange Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/5hECQEEq5cKK-uCSLsKI8yYe1c6MVPS1SHbW-wRR85kSG_L-jEWLxNbMc-K0qz1bkEUq0wPxvEhQvDBwp04BCg=s90'],
#   u'sourceDisplayName': u'Skinny Ms',
#   u'totalTimeInSeconds': 2400},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.3333333333333333,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.0},
#   u'id': u'Lemon-Butter-Chicken-1602780',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/0hUr9PBkyzBDiH4v3RlcO_2lJJKrRjJNn822PnW3gvYHmxJWUxDr5VFO6ufCAu316y8IkwJG_9cPK5478EC3Tg=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'kosher salt',
#    u'black pepper',
#    u'olive oil',
#    u'lemon',
#    u'butter'],
#   u'rating': 4,
#   u'recipeName': u'Lemon Butter Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/oYiXmqN3m-ddgg4Oe_d00qXFpWkQ1e-Xli-gqVxGnrHFfIlhA4U62R1FRY8VXrqcfsuP-S0-izCqpDTGDYSR=s90'],
#   u'sourceDisplayName': u'Dariuscooks.Com',
#   u'totalTimeInSeconds': 2100},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.5,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Garlic-Chicken-Piccata-1701575',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/zM6qeM02Z4_XbuP6fViR5fhTav71sm3SUolVH53sFNQ96m65flGEvobwZ1kRx317cMoTUS0yCVaQYBehR5Zf=s90-c'},
#   u'ingredients': [u'chicken breast halves',
#    u'flour',
#    u'olive oil',
#    u'butter',
#    u'garlic',
#    u'clove',
#    u'capers',
#    u'wine',
#    u'chicken stock',
#    u'lemon',
#    u'salt',
#    u'pepper',
#    u'fresh parsley'],
#   u'rating': 4,
#   u'recipeName': u'Garlic Chicken Piccata',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/H0cH7l6xFBooRaPhlunBmdzWhIlMDrOZm6Q_qPARf7-U05e1WoZVsUBE36eMCw1mUb6ACLBAQeHJjMUvEM432g=s90'],
#   u'sourceDisplayName': u'Served From Scratch',
#   u'totalTimeInSeconds': 3900},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Kid-Friendly']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.16666666666666666,
#    u'sour': 0.3333333333333333,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Baked-Pesto-Chicken-1687730',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/VP2H7BwkhPlbsEi8gcNFbc7CH3TH4NiYuKpFtLPiez1l7o8pt_srMDNNaF4X-W7T9uRwxrtfNpsuDkXDZa-UgZM=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breast halves',
#    u'pesto',
#    u'plum tomatoes',
#    u'shredded mozzarella cheese'],
#   u'rating': 3,
#   u'recipeName': u'Baked Pesto Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/81Pst_dsNin2jjUbLnRGY7NzqkEOIHiqYO9jeW2WqJireXy7pdFg8Neq-alIS9um-uUKB37NtMLK1QtLiTvODg=s90'],
#   u'sourceDisplayName': u'Meals',
#   u'totalTimeInSeconds': 2400},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': None,
#   u'id': u'One-Pot-Chicken-Bacon-Chipotle-Alfredo-1636699',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/xSTzQ-ikpVhbWaWdF5RAuqcKgNAd0kgNhGWYyZeavZtG3NQ4MO5J00CGpvPHmqH2Flbu3K22AEmCNTM8zRaCDw=s90-c'},
#   u'ingredients': [u'mixed salad greens',
#    u'Progresso\u2122 Chicken Broth',
#    u'half & half',
#    u'shredded parmesan cheese',
#    u'grilled chicken strips',
#    u'bacon',
#    u'parsley'],
#   u'rating': 3,
#   u'recipeName': u'One-Pot Chicken-Bacon-Chipotle Alfredo',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/2z1KK602wWrnErAM3WCRCb6CDdU7soyiWGTvH-j6iALFYTtZiSZzooc2cX6sWavlNC0mi5xAhedBQzP60DxjsHI=s90'],
#   u'sourceDisplayName': u'Tablespoon',
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.5,
#    u'piquant': 0.8333333333333334,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Jerk-Chicken-with-Pineapple-Salsa-1703129',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/bO6HMx4bJwNBOSt97vTkdDqMhZKmXZQDoGSIpU_dTkU8fGc0DcQ20SG3E-sadOcpvepEK7QPSFNhKfigZcERyg=s90-c'},
#   u'ingredients': [u'green onions',
#    u'lime',
#    u'olive oil',
#    u'brown sugar',
#    u'soy sauce',
#    u'fresh ginger',
#    u'allspice',
#    u'ground black pepper',
#    u'garlic',
#    u'bay leaves',
#    u'habanero pepper',
#    u'boneless skinless chicken breasts',
#    u'pineapple salsa'],
#   u'rating': 4,
#   u'recipeName': u'Jerk Chicken with Pineapple Salsa',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/UR-8oAGQxwei1Y69HcxHZ4yQdDBYyQKjjhziAiM-jKnsN4vMJalA_fT8Syyj_DS5RQGwRuWF_MT3vIfVJEz8=s90'],
#   u'sourceDisplayName': u'Dinners, Dishes and Desserts',
#   u'totalTimeInSeconds': 5100},
#  {u'attributes': {u'course': [u'Main Dishes'],
#    u'cuisine': [u'Kid-Friendly', u'Southern & Soul Food']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.16666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'The-Ultimate-Southern-Fried-Chicken-1682151',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/-kfK40wo7L9YyjFpnvq7byBMx1CMEfd4uM9br6t14ntLCJ6cMtz7PBJOD_tX_4gCTMYa-9z_nSeL6CfCd5qSWg=s90-c'},
#   u'ingredients': [u'large eggs',
#    u'kosher salt',
#    u'all-purpose flour',
#    u'corn starch',
#    u'garlic powder',
#    u'paprika',
#    u'crushed red pepper',
#    u'freshly ground black pepper',
#    u'chicken',
#    u'vegetable oil'],
#   u'rating': 3,
#   u'recipeName': u'The Ultimate Southern Fried Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/OqGxI5vYPa2SrkNOjleKCy-jmhybQ1aBCxaIbuAH0Qb9tulJlqxEBmFx-8KrG7OYK6_6AKgNv1-PQ4vRTQtBrzY=s90'],
#   u'sourceDisplayName': u'Food & Wine',
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Lunch', u'Main Dishes'],
#    u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'Baked-Chicken-Parmesan-1639330',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/WXH8MindikAgbUznzx8kDJXtjBLTtbgfD0otK5pcdwL0lUR9-zOuYba2y6RsaxWYKJl1WMgzP7DWKYje2zLhcg=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'seasoned bread crumbs',
#    u'grated parmesan cheese',
#    u'butter',
#    u'reduced fat mozzarella',
#    u'marinara sauce',
#    u'cooking spray'],
#   u'rating': 4,
#   u'recipeName': u'Baked Chicken Parmesan',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/q6yZ_0aX3A-lqyon7dE7WN75n7T-RLgOSFKUnX-D7-8h_MMn0IKgPn0OV6vw9FGeTwU6sJX3y2FXZi9n3AYTnjs=s90'],
#   u'sourceDisplayName': u'Enjoy cooking',
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Main Dishes'],
#    u'cuisine': [u'Barbecue', u'Greek']},
#   u'flavors': None,
#   u'id': u'Greek-Chicken---Paleo-1623596',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/T0Yba02cZ6Sr8IIHoh-X1ysw1hJ2VpNZZ4HRVi5MEqA9jSP9SRd0EaK26ilGvfMod_gkCWx1fnne1bVoFTqMpw=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breast halves',
#    u'olive oil',
#    u'chopped garlic',
#    u'fresh rosemary',
#    u'chopped fresh thyme',
#    u'fresh oregano',
#    u'lemon'],
#   u'rating': 4,
#   u'recipeName': u'Greek Chicken - Paleo',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/IauDqKMihkLckofminkDKjeyV1MdBVZbPheVWUD82vf7LcwdpeXf8kS38w4tWEtauqHI7yvm0kX8JL1l0-AXLQ=s90'],
#   u'sourceDisplayName': u'Jessy and Melissa',
#   u'totalTimeInSeconds': 174600},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Teriyaki-Chicken-1704307',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/DyCEQB5rqILhwx-WTnmBFMS4J87Yo8fuSbqvM4rL0A5lrFV8v3EqExohK42Md13TyzTxeETpvA8VBMh1zzWkjQ=s90-c'},
#   u'ingredients': [u'soy sauce',
#    u'vegetable oil',
#    u'brown sugar',
#    u'ground ginger',
#    u'garlic powder',
#    u'chicken drumsticks'],
#   u'rating': 4,
#   u'recipeName': u'Teriyaki Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/rcPkia4RF3aWX7A_p7Znu5NBdtoyPK5nG2bI8rlBIRu2WvImdzzm6VeqYku0xKxuHpbgt8UwzwcIRkgFSqOi=s90'],
#   u'sourceDisplayName': u"Lynn's Kitchen Adventures",
#   u'totalTimeInSeconds': 4200},
#  {u'attributes': {u'course': [u'Lunch']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.0,
#    u'salty': 0.6666666666666666,
#    u'sour': 0.6666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-Cashew-Spinach-Wraps-1701367',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/r4KT4H5GGrXBKXeUnYyxNuMo97nJbXylzyFAq52_clpgCg5k2UDkAEpHV3fDrQCPqLLAo4yVGVLIvU4orVMWJA=s90-c'},
#   u'ingredients': [u'cooked chicken',
#    u'dried apricot',
#    u'diced celery',
#    u'cashew nuts',
#    u'green onions',
#    u'salt',
#    u'black pepper',
#    u'plain greek yogurt',
#    u'mayonnaise',
#    u'fresh spinach leaves',
#    u'spinach'],
#   u'rating': 4,
#   u'recipeName': u'Chicken Cashew Spinach Wraps',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/K_s3gel2YgBme8OvZgH_WkmRF5th2HJzyra85LfVLyEpB8ep3xY8fNtGqnx4jzn1ai4EwJdab4v4yDLdyLek=s90'],
#   u'sourceDisplayName': u'The Essential Baker',
#   u'totalTimeInSeconds': 1500},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.6666666666666666,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Grilled-Chili-Chicken-Breasts-1695964',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/A12s98Jky1PVLkB-Koz2Gd053UPiCLtthasfoVjfQp58B2rI0Box2r41kbOlDnlpgJqc5NJSWdnmQZIozOCld2A=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'soy sauce',
#    u'extra-virgin olive oil',
#    u'curry powder',
#    u'garlic powder',
#    u'onion powder',
#    u'cayenne pepper'],
#   u'rating': 4,
#   u'recipeName': u'Grilled Chili Chicken Breasts',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/SWPOdOn4HC7btle8ev6n1TqX_2TmG9gjobVKpXAWDkOO6uxWUSvka6gRMceUuu-hjwHidFhY1ajMulN_dzVUXlM=s90'],
#   u'sourceDisplayName': u'No Fail Recipes',
#   u'totalTimeInSeconds': 2400},
#  {u'attributes': {},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.5,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.0},
#   u'id': u'Chicken-Pate-1705074',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/CSgHR4FMwVDqP1vN64q1MAXYkm1oapV9qOWByFyW5U-yjaMLAacd_iTOfB2VNsyNPoZtpn8hjepQ6dKhu6kIzg=s90-c'},
#   u'ingredients': [u'chicken fillets', u'salt', u'spices'],
#   u'rating': 4,
#   u'recipeName': u'Chicken Pate',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/Vu0ZuSmkSeqntUjxzQl-Zz-nIkqqc4u_Exc_EhRUebB3LqLaBxxJGWUz4ZrbxJIE2oNOb9gfQaUzAPMJWk7VPg=s90'],
#   u'sourceDisplayName': u'ladiesboxx',
#   u'totalTimeInSeconds': None},
#  {u'attributes': {u'course': [u'Main Dishes', u'Lunch']},
#   u'flavors': None,
#   u'id': u'Buffalo-Chicken-Sloppy-Joes-1703842',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/KiIQerpwvUj4k0D53ObT5L7M7zggj0ZMGBVkpFwIsW0FOXgFT5_mDBp49pUB1SoHMu7MrF2b2n_YjcJNOwkveQ=s90-c'},
#   u'ingredients': [u'ground chicken',
#    u'tomato sauce',
#    u'buffalo sauce',
#    u'onions',
#    u'buns',
#    u'crumbled blue cheese'],
#   u'rating': 4,
#   u'recipeName': u'Buffalo Chicken Sloppy Joes',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/c3xnaKikzrYPLZ1T2Jn106PbdqoRw50em8X_Ng2oU4Cj1d10kt9P_-InVWOPIks2dku1BE06owCEqJ04N22b-g=s90'],
#   u'sourceDisplayName': u'Madame Deals',
#   u'totalTimeInSeconds': 1800},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.3333333333333333,
#    u'piquant': 0.3333333333333333,
#    u'salty': 0.5,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.3333333333333333},
#   u'id': u'Slow-Cooker-Honey-Sesame-Chicken-1704099',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/E0gQwMSeArdZuHZnwJfKS2Zb3kMbBUHIrgZB353CpaLvkW29BPcHiod5Cy-OVxbCvGSaUAlXpZ2ayB-nGI8L=s90-c'},
#   u'ingredients': [u'boneless chicken thighs',
#    u'ketchup',
#    u'low sodium soy sauce',
#    u'rice vinegar',
#    u'honey',
#    u'Sriracha',
#    u'sesame oil',
#    u'ginger',
#    u'garlic cloves',
#    u'black pepper',
#    u'broccoli florets',
#    u'bell pepper',
#    u'rice',
#    u'sesame seeds'],
#   u'rating': 4,
#   u'recipeName': u'Slow Cooker Honey Sesame Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/PlbRSbJnyymxnXpqEMx-QIq-_6Gr2abb10wMCLtEYtamBfUuE5XdbcuTWby2oCK8QXDnS6ocQJgai9yU95Ew3X0=s90'],
#   u'sourceDisplayName': u"Hezzi-D's Books and Cooks",
#   u'totalTimeInSeconds': 29700},
#  {u'attributes': {u'course': [u'Main Dishes'], u'holiday': [u'Sunday Lunch']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.0},
#   u'id': u'Baked-Lemon-Chicken-1623832',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/rqQsCUZZ6qjT2qkUrHja6LpVrJPdsd-01R5I4weG1VWfJs3MfUhdJX9eCve4QWO7mk7-cHZOVKBPNP12aksCG9I=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'garlic',
#    u'melted butter',
#    u'lemon juice',
#    u'fresh thyme leaves',
#    u'kosher salt',
#    u'cracked black pepper',
#    u'lemon slices',
#    u'thyme sprigs'],
#   u'rating': 4,
#   u'recipeName': u'Baked Lemon Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/7TEkeL0XQ_nsTo1EgHin2NDciyCkRt3WZFmPEpeJiwcNM7X9S0sFIdoBs8dzQyj9wgQnZGaGUttTVNLhkJB9PSs=s90'],
#   u'sourceDisplayName': u'Gimme Some Oven',
#   u'totalTimeInSeconds': 2400},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.6666666666666666,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.5,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Paula-Deens-amazing-chicken-casserole-1679543',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/WNDxtqpO_sWZ3dwuwFWf48wPN--yZydNkYxRKyss9mD99sPqyQrkEVkRimhJN83qCXfaoQjuG2D1-zMc9yMVCA=s90-c'},
#   u'ingredients': [u'cooked chicken',
#    u'pasta',
#    u'butter',
#    u'onions',
#    u'garlic cloves',
#    u'flour',
#    u'sour cream',
#    u'milk',
#    u'cheese',
#    u'red pepper flakes',
#    u'salt',
#    u'pepper'],
#   u'rating': 4,
#   u'recipeName': u'Paula Deen\u2019s amazing chicken casserole',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/dZ70S60XbO8ZtsD4C9KyAddJxrvtXS5yL9zAbula1gGLF5KDH9v_LwTtAXUMM3V3K0_SORqWcK3TpVzj6OPvIQ=s90'],
#   u'sourceDisplayName': u'Examiner',
#   u'totalTimeInSeconds': 3900},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.0},
#   u'id': u'2-ingredient-Paprika-Chicken-1650890',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/ppcI4KBVHl8fgismHDv3INVhRq2dFGv5ZDDKeichE7gTCMBrc1INBpateyFgwYSLvHU1ic01zwWMr93tzLwf8Q=s90-c'},
#   u'ingredients': [u'boneless skinless chicken thighs',
#    u'hungarian paprika',
#    u'olive oil',
#    u'salt'],
#   u'rating': 4,
#   u'recipeName': u'2-ingredient Paprika Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/n3uRidkImx_OhDrmbtShIAnGpLqZMuRpj-6D5UTsGF0cynMirIxLt7NtwRrMUw7g0A6NbCfbRh6_Kc5TNCueZQ=s90'],
#   u'sourceDisplayName': u"Viktoria's Table",
#   u'totalTimeInSeconds': 3900},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.3333333333333333,
#    u'piquant': 0.6666666666666666,
#    u'salty': 0.6666666666666666,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-Fajita-Foil-Packet-Meal-1684657',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/w2ZW-3QxnVp9vThqjp3QwwH98w8K0F6Uin78-UzEy5jHQYprSF_5Pgq26qC53Aatxr6JVOvG3nuttetWkvzo6lg=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'bell pepper',
#    u'purple onion',
#    u'chili powder',
#    u'cumin',
#    u'garlic powder',
#    u'onion powder',
#    u'salt'],
#   u'rating': 4,
#   u'recipeName': u'Chicken Fajita Foil Packet Meal',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/wzqlE_EfbJZDmaA6scl5rWeJSmYAeDPg9u5KjDjyI_AKP4AhCOdrlnXOEona-3yQ7RUlizNdOmBUoEOpU7Qy3Fc=s90'],
#   u'sourceDisplayName': u'Real Housemoms',
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.16666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-with-Rice-in-one-pot-1623406',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/ebJMzqtZXr-LUAkpWYGC71KjAxowdaWTZ9IarnS28pthWqVAQN1VONVnzz1n2Dwn926bzIpx6QM11M39hIw_Fzw=s90-c'},
#   u'ingredients': [u'chicken thighs',
#    u'extra-virgin olive oil',
#    u'onions',
#    u'carrots',
#    u'garlic',
#    u'rice',
#    u'salt',
#    u'pepper',
#    u'water'],
#   u'rating': 4,
#   u'recipeName': u'Chicken with Rice in one pot',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/hy3PtuuJWfkYobeke_lEVk-2pJXx6Wda655Wn0h6H6502RgP-IDlsqMUgJ28hSJWBqwTZigz08_2DFIi86LFBQ=s90'],
#   u'sourceDisplayName': u'Image Cooking',
#   u'totalTimeInSeconds': None},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Indian']},
#   u'flavors': None,
#   u'id': u'Badami-Chicken---Almond-Milk-Curry-1702076',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/frB5_wLDSnp1pqnZLXS4Ku9N0EYP3mHdHuWmRxQq4J2Bb3XE4R1-yiRzCg6fBN0CvIjj6IuAiPdGJ59nRi2tBQs=s90-c'},
#   u'ingredients': [u'chicken thighs',
#    u'onions',
#    u'garlic',
#    u'ginger',
#    u'green chilies',
#    u'ground turmeric',
#    u'diced tomatoes',
#    u'oil',
#    u'kala jeera',
#    u'cinnamon sticks',
#    u'bay leaf',
#    u'unsweetened almond milk',
#    u'yoghurt',
#    u'coriander powder',
#    u'ground cumin',
#    u'ground cardamom',
#    u'kasuri methi',
#    u'salt',
#    u'garam masala'],
#   u'rating': 4,
#   u'recipeName': u'Badami Chicken - Almond Milk Curry',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/170k1psnbWJTfXbY-wCfZEu-Cxo3C78SpNkKSrev5q0BDXwEjKXbUNHnMD2k02yCn1_eKPVlDSpNs1ye_6CTGw=s90'],
#   u'sourceDisplayName': u"Whitbit's Indian Kitchen",
#   u'totalTimeInSeconds': 3600},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.0},
#   u'id': u'Everyday-Baked-Chicken-1581195',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/E8ogt9JcF7TsQOZw7mtPi0yMhdPAq4i_qJYhx4Mw9LbSh2kSxAM9G6kWGHwlLLxwkXPNRQLRUfz-a2xt8Epu43Q=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'kosher salt',
#    u'black pepper',
#    u'onion powder',
#    u'garlic powder',
#    u'oregano',
#    u'paprika'],
#   u'rating': 4,
#   u'recipeName': u'Everyday Baked Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/rhx7mViMilCxneHENrmbFTOFPm2CWgoGjtJKATlrhlbFhQ5jRal-AMlPwnf1-hAyCZxrHCw7nIQ9leIUU3WKVHs=s90'],
#   u'sourceDisplayName': u'Motion Mom',
#   u'totalTimeInSeconds': 1800},
#  {u'attributes': {u'course': [u'Main Dishes', u'Lunch'],
#    u'cuisine': [u'Southwestern']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.5,
#    u'salty': 0.6666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-and-Avocado-Burritos-1704783',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/eeB9rCeMVPDhHZxPEb437Z9AlQu4bPu0NCfc2xoWcOeca3p1ujmeqrr7Lv5tgsqcGL-2YroEf3-0ODkUSUIt7qI=s90-c'},
#   u'ingredients': [u'tortillas',
#    u'cooked chicken',
#    u'avocado',
#    u'monterey jack',
#    u'salsa verde',
#    u'sour cream',
#    u'cilantro'],
#   u'rating': 4,
#   u'recipeName': u'Chicken and Avocado Burritos',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/3A0pEbxCtYK_UK3gpCI3GHzzAvBpNTVH0Jauu0es3lpU86iTKcfQu4ggP0JkGvhHXuPVTedExLWPdMl8mchKdLo=s90'],
#   u'sourceDisplayName': u'Closet Cooking',
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'Parmesan-Chicken-Mini-Pies-685394',
#   u'imageUrlsBySize': {u'90': u'http://lh6.ggpht.com/_wrxTIqsE0MXud2-GGyAxQiAzVbKfQgY-2jvhtNGvwKrkWi2zBNQPfrgDgU-mjlP1OdvtWF70fvtItzZoYrt=s90-c'},
#   u'ingredients': [u'dough',
#    u'Tyson\xae frozen popcorn chicken pieces',
#    u'tomato sauce',
#    u'shredded parmesan cheese'],
#   u'rating': 4,
#   u'recipeName': u'Parmesan Chicken Mini Pies',
#   u'smallImageUrls': [u'http://lh5.ggpht.com/_8h6rpOPQqn7wTfjgfI-SPMRE0EPQmI612KFCRlanaMcTb1-8gXv0c4ewV4qOTdc4_EmZlv7mrAYjIN9JZscaDQ=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 1500},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 1.0,
#    u'meaty': 1.0,
#    u'piquant': 0.0,
#    u'salty': 1.0,
#    u'sour': 1.0,
#    u'sweet': 1.0},
#   u'id': u'Beer-Can-Chicken-1637442',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/JyOvQ3GOyDDiCe5btUqg6l2oL9-iqwQ-sxX37ZNebBfN6qecZYKHTHeoTmITgbmRHQMPd7lZhWhV69oV27C2=s90-c'},
#   u'ingredients': [u'chicken',
#    u'salt',
#    u'fresh thyme',
#    u'garlic powder',
#    u'onion powder',
#    u'black pepper',
#    u'vegetable oil',
#    u'beer'],
#   u'rating': 3,
#   u'recipeName': u'Beer Can Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/OlJR7_Ga81cq0KXo0ru7PStGQaUg5RTvWm2W-SlD5IjRQMosS3XrYUamGpFF4-U0IzU0Pqau3u_rlFkYx8s7=s90'],
#   u'sourceDisplayName': u'Perdue.com',
#   u'totalTimeInSeconds': 6000},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.5,
#    u'sweet': 0.0},
#   u'id': u'CHICKEN-BREASTS-WITH-GARLIC-AND-PARSLEY-1678533',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/jxMp_NUTX9KLBLhFnO1JNHGquPEJRKIsykZrh0b4-K2IX9mDr7tD6evxwO85fCEKKCWtd5RKG3WkaFT0atp99U4=s90-c'},
#   u'ingredients': [u'boneless chicken breast',
#    u'flour',
#    u'salt',
#    u'pepper',
#    u'oil',
#    u'garlic',
#    u'fresh parsley',
#    u'butter'],
#   u'rating': 4,
#   u'recipeName': u'CHICKEN BREASTS WITH GARLIC AND PARSLEY',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/PUiQXvdls6AutTxs5bntntLfva3FZFt2D8Rhav9x95ENxuzGmdiyHivOH33gcRrKlydFuNdf1NgaZAvC42hb6WU=s90'],
#   u'sourceDisplayName': u"Linda's Low Carb Menus",
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'SHREDDED-CHICKEN-TACOS-1680208',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/hlpwQGvrd0w6wCoS1NT5tYrVGnqpLVq8A8bC3sAnI11iuS0Ai8xuhpIVrGYvmZN3HbPCD27GPeTzklwSto2S8w=s90-c'},
#   u'ingredients': [u'taco seasoning',
#    u'chicken broth',
#    u'boneless skinless chicken breasts',
#    u'salsa'],
#   u'rating': 4,
#   u'recipeName': u'SHREDDED CHICKEN TACOS',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/84Xeq2o4y1IMZtM9_7rpjHujimx2VWkyZlD_ar87-b8QTy7dXFK_s_qQAupRxpbbukGenq2DkR9RfmYhbaHt=s90'],
#   u'sourceDisplayName': u'Enjoy cooking',
#   u'totalTimeInSeconds': 2100},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Asian']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.5,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.5},
#   u'id': u'Crispy-Sesame-Chicken-with-a-Sticky-Asian-Sauce-1690758',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/fffnh9iuQAsbl0pu_ks6qwprumQk8T4k3XnGmHV5Qtfmgqh7Tye0k0rK-w2xiQZJHqrxZ37ZmnWXY3DKs9_1lA=s90-c'},
#   u'ingredients': [u'olive oil',
#    u'eggs',
#    u'corn flour',
#    u'all-purpose flour',
#    u'salt',
#    u'pepper',
#    u'garlic salt',
#    u'paprika',
#    u'chicken breast fillets',
#    u'sauce',
#    u'garlic',
#    u'Chinese rice vinegar',
#    u'honey',
#    u'sweet chili sauce',
#    u'ketchup',
#    u'brown sugar',
#    u'soy sauce',
#    u'rice',
#    u'sesame seeds',
#    u'spring onions'],
#   u'rating': 4,
#   u'recipeName': u'Crispy Sesame Chicken with a Sticky Asian Sauce',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/0F50u2sWhT_oPNEIvrZdZ5lk7VXe672c-ezunbqEr86OPUBRTOHlqFEYztlnzThFW_by9BMJxuOIwTSCpwgs=s90'],
#   u'sourceDisplayName': u'Kitchen Sanctuary',
#   u'totalTimeInSeconds': 1800},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.16666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-_-Dumpling-Casserole-1684937',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/YfZ4524plaWmBLHBEiM_pGHVUdkZfUoleeYPAKrU7EXrin_8iwPPZpK7seZc-tbWBAzgCMQTch77ZNqB2LYsCXw=s90-c'},
#   u'ingredients': [u'chicken',
#    u'all-purpose flour',
#    u'milk',
#    u'unsalted butter',
#    u'cream of chicken soup',
#    u'chicken broth',
#    u'salt',
#    u'black pepper'],
#   u'rating': 4,
#   u'recipeName': u'Chicken & Dumpling Casserole',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/Z-lkljOUM4VFX_43FlbC-hWwplqHucgM663iqt3CXMPOBw7VPfLnBukFCHDAZCrlAe5j42BWezpChmvNAC20-tA=s90'],
#   u'sourceDisplayName': u'HRecipes.com',
#   u'totalTimeInSeconds': 6300},
#  {u'attributes': {u'course': [u'Main Dishes'],
#    u'cuisine': [u'Barbecue', u'Hawaiian']},
#   u'flavors': None,
#   u'id': u'Hawaiian-Chicken-Kabobs-1683785',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/VhFs2koEaCDU1b5MnUFduoEfUoDuwcF2CZ3N291D3p0FNF8lViOw4BbObHKiQtePZ8lgpttIkCN7mo8jRA8A84M=s90-c'},
#   u'ingredients': [u'bbq sauce',
#    u'pineapple juice',
#    u'boneless skinless chicken breasts',
#    u'mushrooms',
#    u'red bell pepper',
#    u'orange bell pepper',
#    u'pineapple',
#    u'green bell pepper',
#    u'purple onion'],
#   u'rating': 4,
#   u'recipeName': u'Hawaiian Chicken Kabobs',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/IyMjckwGVz9B6mk6Uh3GAcD6-ch5rCJpkjg0np7H9rd8HYmrtT11MBM7MWj7L9ugmFUt0W7uKaoV25G--8WVsjg=s90'],
#   u'sourceDisplayName': u'Spend with Pennies',
#   u'totalTimeInSeconds': 2580},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': None,
#   u'id': u'Lemon-Butter-Chicken-Breasts-1690972',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/VmcMOu0bZz4_d1f_RkBBEyZY5iFznDhX1znR22uFzEk7RNfi3waSGWZX_g78Kl6r4NGCUGPzgP_ATC2QTkPrW8s=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breast halves',
#    u'all-purpose flour',
#    u'salt',
#    u'lemon pepper seasoning',
#    u'butter',
#    u'lemon',
#    u'lemon juice',
#    u'cooked rice'],
#   u'rating': 3,
#   u'recipeName': u'Lemon Butter Chicken Breasts',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/qfr2TlGUO_dearJCYzQT9Y04lUQtQhsFKiAWYGqeBDqYgdgYcIqItEN-FSwl68hNYLAheqR-VmoSN2xLHgcytw=s90'],
#   u'sourceDisplayName': u'Better Homes and Gardens',
#   u'totalTimeInSeconds': 1800},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': None,
#   u'id': u'Buffalo-Chicken-Crescent-Ring-768364',
#   u'imageUrlsBySize': {u'90': u'http://lh5.ggpht.com/5lntnT8m0i0KPy7jgqq9h74SZvypAQ4wee8Qf1QsgrBX-cJ1LhE2UxNo77xHu0rSjMLukIEo9V1SIHj3_9ZAmw=s90-c'},
#   u'ingredients': [u'cream cheese',
#    u'hot sauce',
#    u'cooked chicken',
#    u'shredded Monterey Jack cheese',
#    u'Pillsbury\u2122 Refrigerated Crescent Dinner Rolls',
#    u'crumbled blue cheese'],
#   u'rating': 4,
#   u'recipeName': u'Buffalo Chicken Crescent Ring',
#   u'smallImageUrls': [u'http://lh6.ggpht.com/6QGrV6cd37Q5OjU9ugqd8rfIFTUGZMClUqFUpNeHPb9IL2eqNYLeD0yZMcUyJWab03lTzqq80ewnsxtY5GdG=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'Pesto-Chicken-Crescent-Ring-768366',
#   u'imageUrlsBySize': {u'90': u'http://lh6.ggpht.com/pG7VDczfsWxB86jpsGdasiKNPyk4aT74XnExrjNAcBwKBOlGD7TB2qbr0EE0Wl-eJY2BLp17XXQfhglACEpwsw=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'basil pesto',
#    u'shredded Monterey Jack cheese',
#    u'Pillsbury\u2122 Refrigerated Crescent Dinner Rolls'],
#   u'rating': 4,
#   u'recipeName': u'Pesto Chicken Crescent Ring',
#   u'smallImageUrls': [u'http://lh3.ggpht.com/j1NsPTVxLuU7esOb5BfbFuJDGQUmzKABElWHKZN6r9BKb8gcu0OB_jI_Cu4ipUQyndQERFvhyy7wEvDp_ao=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Asian']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.5,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.3333333333333333},
#   u'id': u'Easy-Chicken-Teriyaki-1683493',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/9r0sFw5oYQC_SEnDyJy7mOaXNQxgeBtxMecfmkyLfrEYMRFQfMtl7a2aV5baNKPU0YPGwFh529NyppwGoJcPFg=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'soy sauce',
#    u'mirin',
#    u'brown sugar',
#    u'white vinegar',
#    u'oil',
#    u'corn starch'],
#   u'rating': 4,
#   u'recipeName': u'Easy Chicken Teriyaki',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/DdlHBvMJGVULZgi9VB8_DKbOWsKz2DOXKjlDzt2iqQNYPkCZQJ59lTIhNaMsvG37D4dqRvcShFIzb-ZtFZqgV0s=s90'],
#   u'sourceDisplayName': u'Melanie Cooks',
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.5,
#    u'piquant': 0.3333333333333333,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.6666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Cilantro-Lime-Chicken-1702564',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/EuIlpI0ax-gH9Iygl90SSGcEyLq2p7vpgqy52vkIVUAj_t7FdgKbKeSBO3iahkrk2gzYlEf89L89CgR9bTYM3w=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'fresh cilantro',
#    u'lime',
#    u'olive oil',
#    u'salt',
#    u'ground cumin',
#    u'cayenne pepper'],
#   u'rating': 4,
#   u'recipeName': u'Cilantro Lime Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/ID9coEPZNWmlQMfJISvxtynTk_pNgRqk9J0Dhgm1CfdD1F68bb5hMgUB5zUmlI_Mkz3s-CX94lkgL65jW7Sv=s90'],
#   u'sourceDisplayName': u'Add a Pinch',
#   u'totalTimeInSeconds': 1500},
#  {u'attributes': {u'course': [u'Lunch'],
#    u'cuisine': [u'Barbecue', u'Kid-Friendly']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.5,
#    u'salty': 0.5,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Easy-BBQ-Chicken-Crescents-685393',
#   u'imageUrlsBySize': {u'90': u'http://lh3.ggpht.com/GoaIXesKJsOZxielWSLft2HlBeInCeTjBBpHj0TsCdbUMul66mcyG4NrefLYQOVYIukloJn0NweBqXA9StBcIw=s90-c'},
#   u'ingredients': [u'Pillsbury\u2122 Refrigerated Crescent Dinner Rolls',
#    u'chicken breast strips',
#    u'barbecue sauce',
#    u'shredded cheddar cheese'],
#   u'rating': 4,
#   u'recipeName': u'Easy BBQ Chicken Crescents',
#   u'smallImageUrls': [u'http://lh5.ggpht.com/PZQYFmdWajIlbSDUqYxT44T24xx8wSFM0-xlF_Hy7YuVLNqYW2ce0tgu_BPUH7XPBKv1V-vl7pJ5frfKZotruw=s90'],
#   u'sourceDisplayName': None,
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes', u'Lunch']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.16666666666666666},
#   u'id': u'15-Minute-Healthy-Roasted-Chicken-and-Veggies-1702651',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/M0flzlCdYkLYfWQz_x1ZcEN9Ef4TIkGyy-R8GZY00nwffjQCjlg777zgHtJZfm-qGy3AMVkAju5okKtaI-_4sw=s90-c'},
# ...
#    u'bacon',
#    u'parsley'],
#   u'rating': 3,
#   u'recipeName': u'One-Pot Chicken-Bacon-Chipotle Alfredo',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/2z1KK602wWrnErAM3WCRCb6CDdU7soyiWGTvH-j6iALFYTtZiSZzooc2cX6sWavlNC0mi5xAhedBQzP60DxjsHI=s90'],
#   u'sourceDisplayName': u'Tablespoon',
#   u'totalTimeInSeconds': 1200},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.5,
#    u'piquant': 0.8333333333333334,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Jerk-Chicken-with-Pineapple-Salsa-1703129',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/bO6HMx4bJwNBOSt97vTkdDqMhZKmXZQDoGSIpU_dTkU8fGc0DcQ20SG3E-sadOcpvepEK7QPSFNhKfigZcERyg=s90-c'},
#   u'ingredients': [u'green onions',
#    u'lime',
#    u'olive oil',
#    u'brown sugar',
#    u'soy sauce',
#    u'fresh ginger',
#    u'allspice',
#    u'ground black pepper',
#    u'garlic',
#    u'bay leaves',
#    u'habanero pepper',
#    u'boneless skinless chicken breasts',
#    u'pineapple salsa'],
#   u'rating': 4,
#   u'recipeName': u'Jerk Chicken with Pineapple Salsa',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/UR-8oAGQxwei1Y69HcxHZ4yQdDBYyQKjjhziAiM-jKnsN4vMJalA_fT8Syyj_DS5RQGwRuWF_MT3vIfVJEz8=s90'],
#   u'sourceDisplayName': u'Dinners, Dishes and Desserts',
#   u'totalTimeInSeconds': 5100},
#  {u'attributes': {u'course': [u'Main Dishes'],
#    u'cuisine': [u'Kid-Friendly', u'Southern & Soul Food']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.16666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'The-Ultimate-Southern-Fried-Chicken-1682151',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/-kfK40wo7L9YyjFpnvq7byBMx1CMEfd4uM9br6t14ntLCJ6cMtz7PBJOD_tX_4gCTMYa-9z_nSeL6CfCd5qSWg=s90-c'},
#   u'ingredients': [u'large eggs',
#    u'kosher salt',
#    u'all-purpose flour',
#    u'corn starch',
#    u'garlic powder',
#    u'paprika',
#    u'crushed red pepper',
#    u'freshly ground black pepper',
#    u'chicken',
#    u'vegetable oil'],
#   u'rating': 3,
#   u'recipeName': u'The Ultimate Southern Fried Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/OqGxI5vYPa2SrkNOjleKCy-jmhybQ1aBCxaIbuAH0Qb9tulJlqxEBmFx-8KrG7OYK6_6AKgNv1-PQ4vRTQtBrzY=s90'],
#   u'sourceDisplayName': u'Food & Wine',
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Lunch', u'Main Dishes'],
#    u'cuisine': [u'Kid-Friendly']},
#   u'flavors': None,
#   u'id': u'Baked-Chicken-Parmesan-1639330',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/WXH8MindikAgbUznzx8kDJXtjBLTtbgfD0otK5pcdwL0lUR9-zOuYba2y6RsaxWYKJl1WMgzP7DWKYje2zLhcg=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'seasoned bread crumbs',
#    u'grated parmesan cheese',
#    u'butter',
#    u'reduced fat mozzarella',
#    u'marinara sauce',
#    u'cooking spray'],
#   u'rating': 4,
#   u'recipeName': u'Baked Chicken Parmesan',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/q6yZ_0aX3A-lqyon7dE7WN75n7T-RLgOSFKUnX-D7-8h_MMn0IKgPn0OV6vw9FGeTwU6sJX3y2FXZi9n3AYTnjs=s90'],
#   u'sourceDisplayName': u'Enjoy cooking',
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {u'course': [u'Main Dishes'],
#    u'cuisine': [u'Barbecue', u'Greek']},
#   u'flavors': None,
#   u'id': u'Greek-Chicken---Paleo-1623596',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/T0Yba02cZ6Sr8IIHoh-X1ysw1hJ2VpNZZ4HRVi5MEqA9jSP9SRd0EaK26ilGvfMod_gkCWx1fnne1bVoFTqMpw=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breast halves',
#    u'olive oil',
#    u'chopped garlic',
#    u'fresh rosemary',
#    u'chopped fresh thyme',
#    u'fresh oregano',
#    u'lemon'],
#   u'rating': 4,
#   u'recipeName': u'Greek Chicken - Paleo',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/IauDqKMihkLckofminkDKjeyV1MdBVZbPheVWUD82vf7LcwdpeXf8kS38w4tWEtauqHI7yvm0kX8JL1l0-AXLQ=s90'],
#   u'sourceDisplayName': u'Jessy and Melissa',
#   u'totalTimeInSeconds': 174600},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Teriyaki-Chicken-1704307',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/DyCEQB5rqILhwx-WTnmBFMS4J87Yo8fuSbqvM4rL0A5lrFV8v3EqExohK42Md13TyzTxeETpvA8VBMh1zzWkjQ=s90-c'},
#   u'ingredients': [u'soy sauce',
#    u'vegetable oil',
#    u'brown sugar',
#    u'ground ginger',
#    u'garlic powder',
#    u'chicken drumsticks'],
#   u'rating': 4,
#   u'recipeName': u'Teriyaki Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/rcPkia4RF3aWX7A_p7Znu5NBdtoyPK5nG2bI8rlBIRu2WvImdzzm6VeqYku0xKxuHpbgt8UwzwcIRkgFSqOi=s90'],
#   u'sourceDisplayName': u"Lynn's Kitchen Adventures",
#   u'totalTimeInSeconds': 4200},
#  {u'attributes': {u'course': [u'Lunch']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.0,
#    u'salty': 0.6666666666666666,
#    u'sour': 0.6666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-Cashew-Spinach-Wraps-1701367',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/r4KT4H5GGrXBKXeUnYyxNuMo97nJbXylzyFAq52_clpgCg5k2UDkAEpHV3fDrQCPqLLAo4yVGVLIvU4orVMWJA=s90-c'},
#   u'ingredients': [u'cooked chicken',
#    u'dried apricot',
#    u'diced celery',
#    u'cashew nuts',
#    u'green onions',
#    u'salt',
#    u'black pepper',
#    u'plain greek yogurt',
#    u'mayonnaise',
#    u'fresh spinach leaves',
#    u'spinach'],
#   u'rating': 4,
#   u'recipeName': u'Chicken Cashew Spinach Wraps',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/K_s3gel2YgBme8OvZgH_WkmRF5th2HJzyra85LfVLyEpB8ep3xY8fNtGqnx4jzn1ai4EwJdab4v4yDLdyLek=s90'],
#   u'sourceDisplayName': u'The Essential Baker',
#   u'totalTimeInSeconds': 1500},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Barbecue']},
#   u'flavors': {u'bitter': 0.8333333333333334,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.6666666666666666,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Grilled-Chili-Chicken-Breasts-1695964',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/A12s98Jky1PVLkB-Koz2Gd053UPiCLtthasfoVjfQp58B2rI0Box2r41kbOlDnlpgJqc5NJSWdnmQZIozOCld2A=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'soy sauce',
#    u'extra-virgin olive oil',
#    u'curry powder',
#    u'garlic powder',
#    u'onion powder',
#    u'cayenne pepper'],
#   u'rating': 4,
#   u'recipeName': u'Grilled Chili Chicken Breasts',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/SWPOdOn4HC7btle8ev6n1TqX_2TmG9gjobVKpXAWDkOO6uxWUSvka6gRMceUuu-hjwHidFhY1ajMulN_dzVUXlM=s90'],
#   u'sourceDisplayName': u'No Fail Recipes',
#   u'totalTimeInSeconds': 2400},
#  {u'attributes': {},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.5,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.0},
#   u'id': u'Chicken-Pate-1705074',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/CSgHR4FMwVDqP1vN64q1MAXYkm1oapV9qOWByFyW5U-yjaMLAacd_iTOfB2VNsyNPoZtpn8hjepQ6dKhu6kIzg=s90-c'},
#   u'ingredients': [u'chicken fillets', u'salt', u'spices'],
#   u'rating': 4,
#   u'recipeName': u'Chicken Pate',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/Vu0ZuSmkSeqntUjxzQl-Zz-nIkqqc4u_Exc_EhRUebB3LqLaBxxJGWUz4ZrbxJIE2oNOb9gfQaUzAPMJWk7VPg=s90'],
#   u'sourceDisplayName': u'ladiesboxx',
#   u'totalTimeInSeconds': None},
#  {u'attributes': {u'course': [u'Main Dishes', u'Lunch']},
#   u'flavors': None,
#   u'id': u'Buffalo-Chicken-Sloppy-Joes-1703842',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/KiIQerpwvUj4k0D53ObT5L7M7zggj0ZMGBVkpFwIsW0FOXgFT5_mDBp49pUB1SoHMu7MrF2b2n_YjcJNOwkveQ=s90-c'},
#   u'ingredients': [u'ground chicken',
#    u'tomato sauce',
#    u'buffalo sauce',
#    u'onions',
#    u'buns',
#    u'crumbled blue cheese'],
#   u'rating': 4,
#   u'recipeName': u'Buffalo Chicken Sloppy Joes',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/c3xnaKikzrYPLZ1T2Jn106PbdqoRw50em8X_Ng2oU4Cj1d10kt9P_-InVWOPIks2dku1BE06owCEqJ04N22b-g=s90'],
#   u'sourceDisplayName': u'Madame Deals',
#   u'totalTimeInSeconds': 1800},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.3333333333333333,
#    u'piquant': 0.3333333333333333,
#    u'salty': 0.5,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.3333333333333333},
#   u'id': u'Slow-Cooker-Honey-Sesame-Chicken-1704099',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/E0gQwMSeArdZuHZnwJfKS2Zb3kMbBUHIrgZB353CpaLvkW29BPcHiod5Cy-OVxbCvGSaUAlXpZ2ayB-nGI8L=s90-c'},
#   u'ingredients': [u'boneless chicken thighs',
#    u'ketchup',
#    u'low sodium soy sauce',
#    u'rice vinegar',
#    u'honey',
#    u'Sriracha',
#    u'sesame oil',
#    u'ginger',
#    u'garlic cloves',
#    u'black pepper',
#    u'broccoli florets',
#    u'bell pepper',
#    u'rice',
#    u'sesame seeds'],
#   u'rating': 4,
#   u'recipeName': u'Slow Cooker Honey Sesame Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/PlbRSbJnyymxnXpqEMx-QIq-_6Gr2abb10wMCLtEYtamBfUuE5XdbcuTWby2oCK8QXDnS6ocQJgai9yU95Ew3X0=s90'],
#   u'sourceDisplayName': u"Hezzi-D's Books and Cooks",
#   u'totalTimeInSeconds': 29700},
#  {u'attributes': {u'course': [u'Main Dishes'], u'holiday': [u'Sunday Lunch']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.0},
#   u'id': u'Baked-Lemon-Chicken-1623832',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/rqQsCUZZ6qjT2qkUrHja6LpVrJPdsd-01R5I4weG1VWfJs3MfUhdJX9eCve4QWO7mk7-cHZOVKBPNP12aksCG9I=s90-c'},
#   u'ingredients': [u'boneless skinless chicken breasts',
#    u'garlic',
#    u'melted butter',
#    u'lemon juice',
#    u'fresh thyme leaves',
#    u'kosher salt',
#    u'cracked black pepper',
#    u'lemon slices',
#    u'thyme sprigs'],
#   u'rating': 4,
#   u'recipeName': u'Baked Lemon Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/7TEkeL0XQ_nsTo1EgHin2NDciyCkRt3WZFmPEpeJiwcNM7X9S0sFIdoBs8dzQyj9wgQnZGaGUttTVNLhkJB9PSs=s90'],
#   u'sourceDisplayName': u'Gimme Some Oven',
#   u'totalTimeInSeconds': 2400},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.6666666666666666,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.5,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Paula-Deens-amazing-chicken-casserole-1679543',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/WNDxtqpO_sWZ3dwuwFWf48wPN--yZydNkYxRKyss9mD99sPqyQrkEVkRimhJN83qCXfaoQjuG2D1-zMc9yMVCA=s90-c'},
#   u'ingredients': [u'cooked chicken',
#    u'pasta',
#    u'butter',
#    u'onions',
#    u'garlic cloves',
#    u'flour',
#    u'sour cream',
#    u'milk',
#    u'cheese',
#    u'red pepper flakes',
#    u'salt',
#    u'pepper'],
#   u'rating': 4,
#   u'recipeName': u'Paula Deen\u2019s amazing chicken casserole',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/dZ70S60XbO8ZtsD4C9KyAddJxrvtXS5yL9zAbula1gGLF5KDH9v_LwTtAXUMM3V3K0_SORqWcK3TpVzj6OPvIQ=s90'],
#   u'sourceDisplayName': u'Examiner',
#   u'totalTimeInSeconds': 3900},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.8333333333333334,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.3333333333333333,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.0},
#   u'id': u'2-ingredient-Paprika-Chicken-1650890',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/ppcI4KBVHl8fgismHDv3INVhRq2dFGv5ZDDKeichE7gTCMBrc1INBpateyFgwYSLvHU1ic01zwWMr93tzLwf8Q=s90-c'},
#   u'ingredients': [u'boneless skinless chicken thighs',
#    u'hungarian paprika',
#    u'olive oil',
#    u'salt'],
#   u'rating': 4,
#   u'recipeName': u'2-ingredient Paprika Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/n3uRidkImx_OhDrmbtShIAnGpLqZMuRpj-6D5UTsGF0cynMirIxLt7NtwRrMUw7g0A6NbCfbRh6_Kc5TNCueZQ=s90'],
#   u'sourceDisplayName': u"Viktoria's Table",
#   u'totalTimeInSeconds': 3900},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.3333333333333333,
#    u'meaty': 0.3333333333333333,
#    u'piquant': 0.6666666666666666,
#    u'salty': 0.6666666666666666,
#    u'sour': 0.8333333333333334,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-Fajita-Foil-Packet-Meal-1684657',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/w2ZW-3QxnVp9vThqjp3QwwH98w8K0F6Uin78-UzEy5jHQYprSF_5Pgq26qC53Aatxr6JVOvG3nuttetWkvzo6lg=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'bell pepper',
#    u'purple onion',
#    u'chili powder',
#    u'cumin',
#    u'garlic powder',
#    u'onion powder',
#    u'salt'],
#   u'rating': 4,
#   u'recipeName': u'Chicken Fajita Foil Packet Meal',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/wzqlE_EfbJZDmaA6scl5rWeJSmYAeDPg9u5KjDjyI_AKP4AhCOdrlnXOEona-3yQ7RUlizNdOmBUoEOpU7Qy3Fc=s90'],
#   u'sourceDisplayName': u'Real Housemoms',
#   u'totalTimeInSeconds': 2700},
#  {u'attributes': {},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.16666666666666666,
#    u'piquant': 0.0,
#    u'salty': 0.16666666666666666,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.16666666666666666},
#   u'id': u'Chicken-with-Rice-in-one-pot-1623406',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/ebJMzqtZXr-LUAkpWYGC71KjAxowdaWTZ9IarnS28pthWqVAQN1VONVnzz1n2Dwn926bzIpx6QM11M39hIw_Fzw=s90-c'},
#   u'ingredients': [u'chicken thighs',
#    u'extra-virgin olive oil',
#    u'onions',
#    u'carrots',
#    u'garlic',
#    u'rice',
#    u'salt',
#    u'pepper',
#    u'water'],
#   u'rating': 4,
#   u'recipeName': u'Chicken with Rice in one pot',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/hy3PtuuJWfkYobeke_lEVk-2pJXx6Wda655Wn0h6H6502RgP-IDlsqMUgJ28hSJWBqwTZigz08_2DFIi86LFBQ=s90'],
#   u'sourceDisplayName': u'Image Cooking',
#   u'totalTimeInSeconds': None},
#  {u'attributes': {u'course': [u'Main Dishes'], u'cuisine': [u'Indian']},
#   u'flavors': None,
#   u'id': u'Badami-Chicken---Almond-Milk-Curry-1702076',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/frB5_wLDSnp1pqnZLXS4Ku9N0EYP3mHdHuWmRxQq4J2Bb3XE4R1-yiRzCg6fBN0CvIjj6IuAiPdGJ59nRi2tBQs=s90-c'},
#   u'ingredients': [u'chicken thighs',
#    u'onions',
#    u'garlic',
#    u'ginger',
#    u'green chilies',
#    u'ground turmeric',
#    u'diced tomatoes',
#    u'oil',
#    u'kala jeera',
#    u'cinnamon sticks',
#    u'bay leaf',
#    u'unsweetened almond milk',
#    u'yoghurt',
#    u'coriander powder',
#    u'ground cumin',
#    u'ground cardamom',
#    u'kasuri methi',
#    u'salt',
#    u'garam masala'],
#   u'rating': 4,
#   u'recipeName': u'Badami Chicken - Almond Milk Curry',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/170k1psnbWJTfXbY-wCfZEu-Cxo3C78SpNkKSrev5q0BDXwEjKXbUNHnMD2k02yCn1_eKPVlDSpNs1ye_6CTGw=s90'],
#   u'sourceDisplayName': u"Whitbit's Indian Kitchen",
#   u'totalTimeInSeconds': 3600},
#  {u'attributes': {u'course': [u'Main Dishes']},
#   u'flavors': {u'bitter': 0.16666666666666666,
#    u'meaty': 0.6666666666666666,
#    u'piquant': 0.16666666666666666,
#    u'salty': 0.8333333333333334,
#    u'sour': 0.16666666666666666,
#    u'sweet': 0.0},
#   u'id': u'Everyday-Baked-Chicken-1581195',
#   u'imageUrlsBySize': {u'90': u'https://lh3.googleusercontent.com/E8ogt9JcF7TsQOZw7mtPi0yMhdPAq4i_qJYhx4Mw9LbSh2kSxAM9G6kWGHwlLLxwkXPNRQLRUfz-a2xt8Epu43Q=s90-c'},
#   u'ingredients': [u'chicken breasts',
#    u'kosher salt',
#    u'black pepper',
#    u'onion powder',
#    u'garlic powder',
#    u'oregano',
#    u'paprika'],
#   u'rating': 4,
#   u'recipeName': u'Everyday Baked Chicken',
#   u'smallImageUrls': [u'https://lh3.googleusercontent.com/rhx7mViMilCxneHENrmbFTOFPm2CWgoGjtJKATlrhlbFhQ5jRal-AMlPwnf1-hAyCZxrHCw7nIQ9leIUU3WKVHs=s90'],
#   u'sourceDisplayName': u'Motion Mom',
#   u'totalTimeInSeconds': 1800}]

# %%
pd.DataFrame(_dict, index=[0])
# Out:
#                                id  rating              recipeName  \
# 0  Everyday-Baked-Chicken-1581195       4  Everyday Baked Chicken
#
#   sourceDisplayName  totalTimeInSeconds
# 0        Motion Mom                1800
